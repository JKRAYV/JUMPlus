# %% [markdown]
# # Import required libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read the csv

# %%
heroes_df = pd.read_csv("charcters_stats.csv")

# %% [markdown]
# # Show the first record from the csv

# %%
print("First record from the dataset:")
heroes_df.head(1)
# Out:
# First record from the dataset:
#       Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0  3-D Man      good            50        31     43          32     25
#
#    Combat  Total
# 0      52    233

# %% [markdown]
# # Show the number of rows and columns

# %%
num_rows, num_columns = heroes_df.shape
print(f"\nNumber of rows: {num_rows}, Number of columns: {num_columns}")
# Out:
# Number of rows: 611, Number of columns: 9

# %% [markdown]
# # Find the amount of characters who fall under each alignment

# %%
alignment_counts = heroes_df['Alignment'].value_counts()
print("\nCharacter count by alignment:")
print(alignment_counts)
# Out:
# Character count by alignment:
# good       432
# bad        165
# neutral     11
# Name: Alignment, dtype: int64

# %% [markdown]
# # Find only the good alignment characters

# %%
good_alignment_characters = heroes_df[heroes_df['Alignment'] == 'good']

# %% [markdown]
# # Show only the first five records from the previous bullet point

# %%
print("\nFirst five records with good alignment:")
print(good_alignment_characters.head())
# Out:
# First five records with good alignment:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 6  Adam Monroe      good            63        10     12         100     71
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 6      64    320

# %% [markdown]
# # Select the top five heroes with the highest speed who have a good alignment

# %%
top_5_fastest_good_alignment = good_alignment_characters.nlargest(5, 'Speed')
print("\nTop five heroes with the highest speed and good alignment:")
print(top_5_fastest_good_alignment)
# Out:
# Top five heroes with the highest speed and good alignment:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 85   Black Bolt      good            75        67    100          84    100
# 229     Flash I      good            63        10    100          50     57
# 230    Flash II      good            63        10    100          60     66
# 231   Flash III      good            63        10    100          60     83
# 232    Flash IV      good            63        10    100          32     59
#
#      Combat  Total
# 85       56    482
# 229      32    312
# 230      32    331
# 231      32    348
# 232      48    312

# %% [markdown]
# # Select five heroes with maximum power who have a good alignment

# %%
top_5_powerful_good_alignment = good_alignment_characters.nlargest(5, 'Power')
print("\nTop five heroes with maximum power and good alignment:")
print(top_5_powerful_good_alignment)
# Out:
# Top five heroes with maximum power and good alignment:
#               Name Alignment  Intelligence  Strength  Speed  Durability  \
# 69   Beta Ray Bill      good            63        80     35          95
# 70        Beyonder      good            88       100     23         100
# 85      Black Bolt      good            75        67    100          84
# 129          Cable      good            88        48     23          56
# 185        Deadman      good            50        10     33         100
#
#      Power  Combat  Total
# 69     100      84    457
# 70     100      56    467
# 85     100      56    482
# 129    100      80    395
# 185    100      42    335

# %% [markdown]
# # Requirement 10: Find out how many superheroes there are with power of 100 with good alignment

# %%
num_heroes_power_100 = good_alignment_characters[good_alignment_characters['Power'] == 100].shape[0]
print(f"\nNumber of superheroes with power 100 and good alignment: {num_heroes_power_100}")
# Out:
# Number of superheroes with power 100 and good alignment: 33

# %% [markdown]
# # Shape them what you got in point 10

# %%
heroes_power_100 = good_alignment_characters[good_alignment_characters['Power'] == 100]
num_rows, num_columns = good_alignment_characters[good_alignment_characters['Power'] == 100].shape
print(f"Shape of 100 power good alignment\nRows: {num_rows}\nColumns: {num_columns}")
# Out:
# Shape of 100 power good alignment
# Rows: 33
# Columns: 9

# %%
print("\nAll records of superheroes with power 100 and good alignment:")
print(heroes_power_100)
# Out:
# All records of superheroes with power 100 and good alignment:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 69       Beta Ray Bill      good            63        80     35          95
# 70            Beyonder      good            88       100     23         100
# 85          Black Bolt      good            75        67    100          84
# 129              Cable      good            88        48     23          56
# 185            Deadman      good            50        10     33         100
# 196        Doctor Fate      good            81        16     25          80
# 198     Doctor Strange      good           100        10     12          84
# 204       Dr Manhattan      good            88        32     42          95
# 226          Firestorm      good            50        53     58          56
# 251               Goku      good            56       100     75          90
# ...

# %% [markdown]
# # Retrieve the first five records with max power and has good alignment

# %%
top_5_max_power_good_alignment = good_alignment_characters.nlargest(5, 'Power')
print("\nFirst five records with the max power and good alignment:")
print(top_5_max_power_good_alignment)
# Out:
# First five records with the max power and good alignment:
#               Name Alignment  Intelligence  Strength  Speed  Durability  \
# 69   Beta Ray Bill      good            63        80     35          95
# 70        Beyonder      good            88       100     23         100
# 85      Black Bolt      good            75        67    100          84
# 129          Cable      good            88        48     23          56
# 185        Deadman      good            50        10     33         100
#
#      Power  Combat  Total
# 69     100      84    457
# 70     100      56    467
# 85     100      56    482
# 129    100      80    395
# 185    100      42    335

# %% [markdown]
# # Draw a bar plot of all superheroes who are having good alignment and a max power of the top five heroes

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=top_5_max_power_good_alignment, x='Name', y='Total', color='green')
plt.title('Top 5 Superheroes with Good Alignment and Maximum Power')
plt.xlabel('Superhero Name')
plt.ylabel('Total Power')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Extract villains who have a bad alignment

# %%
villains_bad_alignment = heroes_df[heroes_df['Alignment'] == 'bad']

# %% [markdown]
# # Show first five records of villains with bad alignment

# %%
print("\nFirst five records of villains with bad alignment:")
print(villains_bad_alignment.head())
# Out:
# First five records of villains with bad alignment:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 4   Abomination       bad            63        80     53          90     55
# 5       Abraxas       bad            88       100     83          99    100
# 11   Air-Walker       bad            50        85    100          85    100
# 16        Amazo       bad            75       100    100         100    100
# 17         Ammo       bad             1         1      1           1      0
#
#     Combat  Total
# 4       95    436
# 5       56    526
# 11      40    460
# 16     100    575
# 17       1      5

# %% [markdown]
# # Show top five fastest super villains in terms of super speed

# %%
top_5_fastest_villains = villains_bad_alignment.nlargest(5, 'Speed')
print("\nTop five fastest super villains:")
print(top_5_fastest_villains)
# Out:
# Top five fastest super villains:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 11       Air-Walker       bad            50        85    100          85
# 16            Amazo       bad            75       100    100         100
# 535  Superboy-Prime       bad            94       100    100         100
# 610            Zoom       bad            50        10    100          28
# 242     General Zod       bad            94       100     96         100
#
#      Power  Combat  Total
# 11     100      40    460
# 16     100     100    575
# 535    100      85    579
# 610     72      28    288
# 242     94      95    579

# %% [markdown]
# # Top five super villains in terms of intelligence

# %%
top_5_intelligent_villains = villains_bad_alignment.nlargest(5, 'Intelligence')
print("\nTop five super villains with highest intelligence:")
print(top_5_intelligent_villains)
# Out:
# Top five super villains with highest intelligence:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 386  Mister Mxyzptlk       bad           113        10     12          14
# 29        Apocalypse       bad           100       100     33         100
# 122         Brainiac       bad           100        28     63          90
# 194      Doctor Doom       bad           100        32     20         100
# 315            Joker       bad           100        10     12          56
#
#      Power  Combat  Total
# 386    100      28    277
# 29     100      60    493
# 122     60      75    416
# 194     93      84    429
# 315     22      90    290

# %% [markdown]
# # Show who is the most dangerous super villain after calculating their total (top 5 only)

# %%
top_5_dangerous_villains = villains_bad_alignment.nlargest(5, 'Total')
print("\nTop five most dangerous super villains:")
print(top_5_dangerous_villains)

# %% [markdown]
# # Draw a histogram for speed of superheroes having fig size 10.5, provide speed in histogram

# %%
plt.figure(figsize=(10.5, 6))
good_alignment_speed = good_alignment_characters['Speed']
plt.hist(good_alignment_speed, bins=20, color='blue')
plt.title('Distribution of Speed for Superheroes with Good Alignment')
plt.xlabel('Speed')
plt.show()

# %% [markdown]
# # -Bonus-
# # Draw a histogram for combat of super villains having fig size 10.5, provide combat in histogram

# %%
plt.figure(figsize=(10.5, 6))
villains_bad_alignment_combat = villains_bad_alignment['Combat']
plt.hist(villains_bad_alignment_combat, bins=20, color='red')
plt.title('Distribution of Combat for Super Villains with Bad Alignment')
plt.xlabel('Combat')
plt.show()

# %% [markdown]
# # Distribution of power by alignment

# %%
sns.boxplot(data=heroes_df, x='Alignment', y='Power', palette='pastel')
plt.title('Distribution of Power by Alignment')
plt.xlabel('Alignment')
plt.ylabel('Power')
plt.show()

# %% [markdown]
# # Power vs. Speed for superheroes

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=heroes_df, x='Power', y='Speed', hue='Alignment', palette='cool', s=100)
plt.title('Power vs. Speed for Superheroes')
plt.xlabel('Power')
plt.ylabel('Speed')
plt.legend(title='Alignment')
plt.show()

# %% [markdown]
# # Correlation heatmap for superhero attributes

# %%
plt.figure(figsize=(10, 8))
correlation_matrix = heroes_df[['Intelligence', 'Strength', 'Speed', 'Durability', 'Power', 'Combat', 'Total']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap for Superhero Attributes')
plt.show()
